# %%
print(5==5)
print(5!=5)
# Out:
# True
# False

# %%
print(5<3)
print(5<=3)
# Out:
# False
# False

# %%
print(5>3)
print(5>=3)
# Out:
# True
# True

# %%
print("a">"z")
print("Z">"A")
# Out:
# False
# True

# %%
# identity vs eqality
a = [1, 2, 3]
b = [1, 2, 3]
a == b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
value = None
if value is None:  # Preferred
    print("No value")

if value == None:  # Works but not idiomatic
    print("No value")
# Out:
# No value
# No value

# %%
'a' in 'apple'
# Out:
# True

# %%
True and True
# Out:
# True

# %%
not True
# Out:
# False

# %%
False or (1/2)
# Out:
# 0.5

# %%
# odd even check
a=int(input("Enter a numnber"))

if (a%2 == 0):
    print("Even")
else:
    print("odd")
# Out:
# odd

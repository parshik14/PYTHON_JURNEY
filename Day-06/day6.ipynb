# %%
with open("input.txt",'r') as file:
    content = file.read()
content
# Out:
# 'this is input file'

# %%
# open mutliple files
with open("input.txt",'r') as inputfile,open ("output.txt",'r') as outputfile:
    content1 = inputfile.read()
    content2 = outputfile.read()

print(content1)
print(content2)
# Out:
# this is input file
# this is output file.

# %%
with open('input.txt','r') as inputfile:
    for line in inputfile:
        print(line.strip())
# Out:
# this is input file line 1
# this is input file line 2

# %%
with open('input.txt','w') as file :
    file.write("text from code")
    file.write("text from line 2")

# %%
with open('input.txt','a') as file :
    file.write("text from code\n")
    file.write("text from line\n")
